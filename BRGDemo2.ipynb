# %%
# !pip install langchain-experimental langchain-community langchain networkx langchain-google-genai langchain-core json-repair tiktoken
# Out:
# Collecting langchain-experimental
#   Downloading langchain_experimental-0.3.4-py3-none-any.whl.metadata (1.7 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.3.16-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.16)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (3.4.2)
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-2.0.9-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.11/dist-packages (0.3.32)
# Collecting json-repair
#   Downloading json_repair-0.35.0-py3-none-any.whl.metadata (11 kB)
# Collecting tiktoken
#   Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.11)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (1.26.4)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.7.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.10.6)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: google-generativeai<0.9.0,>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from langchain-google-genai) (0.8.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core) (4.12.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.19.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.155.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.25.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.67.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.26.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.66.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.9)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.1.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.62.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (3.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_experimental-0.3.4-py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.2/209.2 kB 6.4 MB/s eta 0:00:00
# Downloading langchain_community-0.3.16-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 28.3 MB/s eta 0:00:00
# Downloading langchain_google_genai-2.0.9-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.7 MB/s eta 0:00:00
# Downloading json_repair-0.35.0-py3-none-any.whl (19 kB)
# Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.1 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading pydantic_settings-2.7.1-py3-none-any.whl (29 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.9 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: filetype, python-dotenv, mypy-extensions, marshmallow, json-repair, httpx-sse, typing-inspect, tiktoken, pydantic-settings, dataclasses-json, langchain-google-genai, langchain-community, langchain-experimental
# Successfully installed dataclasses-json-0.6.7 filetype-1.2.0 httpx-sse-0.4.0 json-repair-0.35.0 langchain-community-0.3.16 langchain-experimental-0.3.4 langchain-google-genai-2.0.9 marshmallow-3.26.1 mypy-extensions-1.0.0 pydantic-settings-2.7.1 python-dotenv-1.0.1 tiktoken-0.8.0 typing-inspect-0.9.0

# %%
import re
import json
import os

def parse_rules_file(rules_file_path):
    """
    Parses a Suricata rules file and extracts relevant information
    :param rules_file_path: Path to the rules file
    :return: A list of dictionaries with extracted rule information
    """
    extracted_data = []
    # Regex pattern to extract msg, classtype, and sid
    rule_pattern = re.compile(
        r'msg:"(?P<msg>.*?)";.*?classtype:(?P<classtype>[^;]+);.*?sid:(?P<sid>\d+);'
    )

    with open(rules_file_path, 'r', encoding='utf-8') as file:
        for line_number, line in enumerate(file, 1):
            line = line.strip()
            # Skip comments and empty lines
            if not line or line.startswith('#'):
                continue

            try:
                match = rule_pattern.search(line)
                if match:
                    suri_rule_msg = match.group('msg')
                    suri_rule_classtype = match.group('classtype')
                    suri_rule_id = match.group('sid')

                    # Append to extracted data
                    extracted_data.append({
                        "suri_rule_id": suri_rule_id,
                        "suri_rule_classtype": suri_rule_classtype,
                        "suri_rule_msg": suri_rule_msg
                    })
                else:
                    print(f"Warning: Line {line_number} does not match expected format.")
            except Exception as e:
                print(f"Error processing line {line_number}: {e}")
    return extracted_data

def save_to_json(data, output_file_path):
    """
    Saves extracted data to a JSON file
    :param data: List of extracted rule data
    :param output_file_path: Path to the output JSON file
    """
    with open(output_file_path, "w", encoding="utf-8") as json_file:
        json.dump(data, json_file, indent=4)
    print(f"Extracted rules saved to {output_file_path}")

if __name__ == "__main__":
    # Input rules file path
    rules_file_path = "testData.rules"  # Replace with your .rules file path

    # Output JSON file path
    output_file_path = "testData.json"

    # Parse rules file
    print(f"Parsing rules file: {rules_file_path}")
    extracted_rules = parse_rules_file(rules_file_path)

    # Save to JSON file
    save_to_json(extracted_rules, output_file_path)

    # Print summary
    print(f"Total rules extracted: {len(extracted_rules)}")
# Out:
# Parsing rules file: testData.rules
# Extracted rules saved to testData.json
# Total rules extracted: 515

# %%
# Set OpenAI API key directly
import os
os.environ['OPENAI_API_KEY'] = ''

# %%
import json
import os
import csv
import time
import re
import openai
from collections import OrderedDict

#############################################
# 1) SETUP: Client, API Key, and Cache
#############################################

client = openai  # or your custom client object
client.api_key = os.getenv("OPENAI_API_KEY")

# Cache to avoid calling the model multiple times for the same rule message
cache = {}

#############################################
# 2) REGEX for extracting msg and classtype
#############################################

MSG_REGEX = re.compile(r'msg:"([^"]+)"', re.IGNORECASE)
CLASSTYPE_REGEX = re.compile(r'classtype:([^;]+);', re.IGNORECASE)

#############################################
# 3) PROMPT CREATION
#############################################

def create_prompt_with_confidence(rule):
    """
    Return a user prompt instructing the LLM to output
    three MITRE techniques + a confidence score rounded upto 2 decimal places for each.
    We include all relevant fields in the text for context.
    """
    return f"""
Map the following Suricata IDS rule to three MITRE ATT&CK techniques,
and provide a confidence score for each technique 0-1 rounded upto 2 decimal places for each.

### Rule:
ID: {rule["suri_rule_id"]}
File Name: {rule["file_name"]}
Action: {rule["action"]}
Protocol: {rule["protocol"]}
Source: {rule["src_addr"]}:{rule["src_port"]}
Destination: {rule["dst_addr"]}:{rule["dst_port"]}
Options: {rule["options"]}
Classification: {rule["suri_rule_classtype"]}
Message: "{rule["suri_rule_msg"]}"

Respond in valid JSON with exactly these fields:
{{
  "most_likely_technique": {{
    "mitre_technique_id": "<Technique ID>",
    "mitre_technique_name": "<Technique Name>",
    "mitre_tactic_id": "<Tactic ID>",
    "mitre_tactic_name": "<Tactic Name>",
    "confidence_score": "<Confidence Score>"
  }},
  "second_most_likely_technique": {{
    "mitre_technique_id": "<Technique ID>",
    "mitre_technique_name": "<Technique Name>",
    "mitre_tactic_id": "<Tactic ID>",
    "mitre_tactic_name": "<Tactic Name>",
    "confidence_score": "<Confidence Score>"
  }},
  "third_most_likely_technique": {{
    "mitre_technique_id": "<Technique ID>",
    "mitre_technique_name": "<Technique Name>",
    "mitre_tactic_id": "<Tactic ID>",
    "mitre_tactic_name": "<Tactic Name>",
    "confidence_score": "<Confidence Score>"
  }}
}}
""".strip()

#############################################
# 4) HELPER: Query the LLM with client.chat
#############################################

def query_llm(prompt, use_gpt4=False):
    """
    Interact with the ChatGPT model using client.chat.completions.create
    (rather than openai.ChatCompletion.create).
    """
    model_name = "gpt-4" if use_gpt4 else "gpt-3.5-turbo"

    system_message = (
        "You are a cybersecurity expert. Your task is to map Suricata IDS rules "
        "to MITRE ATT&CK techniques, providing a confidence score for each technique."
    )

    response = client.chat.completions.create(
        model=model_name,
        messages=[
            {"role": "system", "content": system_message},
            {"role": "user", "content": prompt},
        ],
        max_tokens=400,
        temperature=0.0
    )
    return response

#############################################
# 5) MAP FUNCTION: calls query_llm
#############################################

def map_rule_to_mitre(rule, use_gpt4=False):
    """
    Query the LLM to map a Suricata rule to MITRE techniques,
    returning JSON with confidence scores.
    """

    rule_msg = rule["suri_rule_msg"]
    if rule_msg in cache:
        print(f"[CACHE HIT] Using cached result for rule message: {rule_msg}")
        return cache[rule_msg]

    # Build the user prompt, now including all fields
    user_prompt = create_prompt_with_confidence(rule)

    try:
        start_time = time.time()
        response = query_llm(user_prompt, use_gpt4=use_gpt4)
        elapsed_time = time.time() - start_time

        response_text = response.choices[0].message.content.strip()
        print(f"[Rule ID: {rule['suri_rule_id']}] Raw response:\n{response_text}\n")

        # Clean up possible JSON code fences
        cleaned_text = (
            response_text
            .replace("```json", "")
            .replace("```", "")
            .strip()
        )

        # Parse JSON
        parsed_response = json.loads(cleaned_text)

        # Quick sanity check: we expect these top-level keys
        required_top_keys = [
            "most_likely_technique",
            "second_most_likely_technique",
            "third_most_likely_technique"
        ]
        for key in required_top_keys:
            if key not in parsed_response:
                raise ValueError(
                    f"Missing '{key}' in JSON for rule ID {rule['suri_rule_id']}."
                )

        cache[rule_msg] = parsed_response
        print(f"Rule ID {rule['suri_rule_id']} mapped in {elapsed_time:.1f}s\n")
        return parsed_response

    except json.JSONDecodeError as e:
        print(f"Error: Invalid JSON for rule ID {rule['suri_rule_id']}: {e}")
        return None
    except Exception as e:
        print(f"Error processing rule ID {rule['suri_rule_id']}: {e}")
        return None

#############################################
# 6) MAIN CSV PROCESSOR
#############################################

def process_csv_and_map_to_mitre(
    csv_input_file,
    json_output_file,
    test_mode=True,
    use_gpt4=False
):
    """
    1) Read Suricata rules from a CSV that has columns:
       file_name, action, protocol, src_addr, src_port, dst_addr, dst_port, options
    2) Extract suri_rule_id, suri_rule_classtype, suri_rule_msg from each row (parsing the 'options' field).
    3) Map each rule to top-3 MITRE techniques with confidence scores.
    4) Write the results to a JSON file, including the original CSV fields.
    """

    rules = []
    with open(csv_input_file, "r", encoding="utf-8") as f:
        reader = csv.DictReader(f)

        for i, row in enumerate(reader, start=1):
            suri_rule_id = f"{row['file_name']}_{i}"

            # Attempt to parse "msg" from the options
            options = row["options"]
            msg_match = MSG_REGEX.search(options)
            if msg_match:
                suri_rule_msg = msg_match.group(1).strip()
            else:
                suri_rule_msg = "(no msg found)"

            # Attempt to parse "classtype" from the options
            classtype_match = CLASSTYPE_REGEX.search(options)
            if classtype_match:
                suri_rule_classtype = classtype_match.group(1).strip()
            else:
                suri_rule_classtype = "(no classtype found)"

            # Build a dictionary with ALL relevant fields
            rule_dict = {
                "suri_rule_id": suri_rule_id,
                "suri_rule_classtype": suri_rule_classtype,
                "suri_rule_msg": suri_rule_msg,
                "file_name": row["file_name"],
                "action": row["action"],
                "protocol": row["protocol"],
                "src_addr": row["src_addr"],
                "src_port": row["src_port"],
                "dst_addr": row["dst_addr"],
                "dst_port": row["dst_port"],
                "options": options
            }
            rules.append(rule_dict)

    print(f"Loaded {len(rules)} rule(s) from CSV: {csv_input_file}")

    # Limit how many we process if test_mode is True
    max_rules = 5 if test_mode else len(rules)
    subset_rules = rules[:max_rules]
    print(f"Processing {len(subset_rules)} rule(s){' (test mode)' if test_mode else ''}...\n")

    mapped_results = []
    for idx, rule in enumerate(subset_rules, start=1):
        print(f"Processing rule {idx}/{len(subset_rules)}: {rule['suri_rule_id']}")
        mapping = map_rule_to_mitre(rule, use_gpt4=use_gpt4)
        if mapping:
            # We'll store all original fields in the final output
            # plus the new MITRE mapping fields.
            result = OrderedDict()

            # Original CSV fields
            result["suri_rule_id"] = rule["suri_rule_id"]
            result["suri_rule_classtype"] = rule["suri_rule_classtype"]
            result["suri_rule_msg"] = rule["suri_rule_msg"]
            result["file_name"] = rule["file_name"]
            result["action"] = rule["action"]
            result["protocol"] = rule["protocol"]
            result["src_addr"] = rule["src_addr"]
            result["src_port"] = rule["src_port"]
            result["dst_addr"] = rule["dst_addr"]
            result["dst_port"] = rule["dst_port"]
            result["options"] = rule["options"]

            # LLM’s JSON fields
            result["most_likely_technique"] = mapping["most_likely_technique"]
            result["second_most_likely_technique"] = mapping["second_most_likely_technique"]
            result["third_most_likely_technique"] = mapping["third_most_likely_technique"]

            mapped_results.append(result)
        else:
            print(f"Skipping rule ID {rule['suri_rule_id']} due to an error.\n")

    # Write output to JSON
    print(f"\nSaving {len(mapped_results)} mapped rules to '{json_output_file}'...")
    with open(json_output_file, "w", encoding="utf-8") as f_out:
        json.dump(mapped_results, f_out, indent=4)

    print(f"Done! Mapped {len(mapped_results)} of {len(subset_rules)} successfully.\n")

#############################################
# 7) ENTRY POINT
#############################################

if __name__ == "__main__":
    # Example usage:
    csv_input_file = "suricata_extracted_rules_random_sampled.csv"
    json_output_file = "testDataMapped_with_confidence.json"

    # Only process 5 rules in test mode
    test_mode = False
    # Switch to True if you want GPT-4
    use_gpt4 = False

    process_csv_and_map_to_mitre(
        csv_input_file=csv_input_file,
        json_output_file=json_output_file,
        test_mode=test_mode,
        use_gpt4=use_gpt4
    )
# Out:
# Streaming output truncated to the last 5000 lines.
# ```
#
# Rule ID emerging-dos.rules_325 mapped in 2.6s
#
# Processing rule 326/497: emerging-dos.rules_326
# [Rule ID: emerging-dos.rules_326] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1498",
#     "mitre_technique_name": "Network Denial of Service",
#     "mitre_tactic_id": "TA0040",
#     "mitre_tactic_name": "Impact",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.70"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1106",
#     "mitre_technique_name": "Native API",
#     "mitre_tactic_id": "TA0007",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.60"
#   }
# }
# ```
#
# Rule ID emerging-dos.rules_326 mapped in 2.5s
#
# Processing rule 327/497: emerging-dos.rules_327
# [Rule ID: emerging-dos.rules_327] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1498",
#     "mitre_technique_name": "Network Denial of Service",
#     "mitre_tactic_id": "TA0040",
#     "mitre_tactic_name": "Impact",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1496",
#     "mitre_technique_name": "Denial of Service",
#     "mitre_tactic_id": "TA0040",
#     "mitre_tactic_name": "Impact",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1499",
#     "mitre_technique_name": "Endpoint Denial of Service",
#     "mitre_tactic_id": "TA0040",
#     "mitre_tactic_name": "Impact",
#     "confidence_score": "0.70"
#   }
# }
# ```
#
# Rule ID emerging-dos.rules_327 mapped in 2.5s
#
# Processing rule 328/497: emerging-phishing.rules_328
# [Rule ID: emerging-phishing.rules_328] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1566",
#     "mitre_technique_name": "Phishing",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.95"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.85"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.80"
#   }
# }
# ```
#
# Rule ID emerging-phishing.rules_328 mapped in 2.5s
#
# Processing rule 329/497: emerging-phishing.rules_329
# [Rule ID: emerging-phishing.rules_329] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.95"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1566",
#     "mitre_technique_name": "Phishing",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.85"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1132",
#     "mitre_technique_name": "Data Encoding",
#     "mitre_tactic_id": "TA0012",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   }
# }
# ```
#
# Rule ID emerging-phishing.rules_329 mapped in 2.7s
#
# Processing rule 330/497: emerging-phishing.rules_330
# [Rule ID: emerging-phishing.rules_330] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1566",
#     "mitre_technique_name": "Phishing",
#     "mitre_tactic_id": "TA0043",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": 0.85
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": 0.75
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1113",
#     "mitre_technique_name": "Screen Capture",
#     "mitre_tactic_id": "TA0009",
#     "mitre_tactic_name": "Collection",
#     "confidence_score": 0.65
#   }
# }
# ```
#
# Rule ID emerging-phishing.rules_330 mapped in 2.4s
#
# Processing rule 331/497: emerging-phishing.rules_331
# [Rule ID: emerging-phishing.rules_331] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1566",
#     "mitre_technique_name": "Phishing",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.95"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1070",
#     "mitre_technique_name": "Indicator Removal on Host",
#     "mitre_tactic_id": "TA0004",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-phishing.rules_331 mapped in 2.3s
#
# Processing rule 332/497: emerging-phishing.rules_332
# [Rule ID: emerging-phishing.rules_332] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1566",
#     "mitre_technique_name": "Phishing",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1134",
#     "mitre_technique_name": "Data Encoding",
#     "mitre_tactic_id": "TA0012",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-phishing.rules_332 mapped in 2.4s
#
# Processing rule 333/497: emerging-phishing.rules_333
# [Rule ID: emerging-phishing.rules_333] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1566",
#     "mitre_technique_name": "Phishing",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.95"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1102",
#     "mitre_technique_name": "Web Service",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-phishing.rules_333 mapped in 2.6s
#
# Processing rule 334/497: emerging-phishing.rules_334
# [Rule ID: emerging-phishing.rules_334] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1566",
#     "mitre_technique_name": "Phishing",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.95"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.85"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.80"
#   }
# }
# ```
#
# Rule ID emerging-phishing.rules_334 mapped in 2.2s
#
# Processing rule 335/497: emerging-phishing.rules_335
# [Rule ID: emerging-phishing.rules_335] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1566",
#     "mitre_technique_name": "Phishing",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.95"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1566",
#     "mitre_technique_name": "Phishing",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.85"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1566",
#     "mitre_technique_name": "Phishing",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.80"
#   }
# }
# ```
#
# Rule ID emerging-phishing.rules_335 mapped in 2.7s
#
# Processing rule 336/497: emerging-phishing.rules_336
# [Rule ID: emerging-phishing.rules_336] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1566",
#     "mitre_technique_name": "Phishing",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.95"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1070",
#     "mitre_technique_name": "Indicator Removal on Host",
#     "mitre_tactic_id": "TA0004",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-phishing.rules_336 mapped in 2.2s
#
# Processing rule 337/497: emerging-phishing.rules_337
# [Rule ID: emerging-phishing.rules_337] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1566",
#     "mitre_technique_name": "Phishing",
#     "mitre_tactic_id": "TA0043",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": 0.95
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": 0.85
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": 0.75
#   }
# }
# ```
#
# Rule ID emerging-phishing.rules_337 mapped in 2.5s
#
# Processing rule 338/497: emerging-malware.rules_338
# [Rule ID: emerging-malware.rules_338] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1027",
#     "mitre_technique_name": "Obfuscated Files or Information",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1106",
#     "mitre_technique_name": "Execution through API",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-malware.rules_338 mapped in 3.4s
#
# Processing rule 339/497: emerging-malware.rules_339
# [Rule ID: emerging-malware.rules_339] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1106",
#     "mitre_technique_name": "Execution through API",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-malware.rules_339 mapped in 3.5s
#
# Processing rule 340/497: emerging-malware.rules_340
# [Rule ID: emerging-malware.rules_340] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Alternative Protocol",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.7"
#   }
# }
# ```
#
# Rule ID emerging-malware.rules_340 mapped in 2.7s
#
# Processing rule 341/497: emerging-malware.rules_341
# [Rule ID: emerging-malware.rules_341] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1106",
#     "mitre_technique_name": "Execution through API",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-malware.rules_341 mapped in 2.6s
#
# Processing rule 342/497: emerging-malware.rules_342
# [Rule ID: emerging-malware.rules_342] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.7"
#   }
# }
# ```
#
# Rule ID emerging-malware.rules_342 mapped in 3.1s
#
# Processing rule 343/497: emerging-malware.rules_343
# [Rule ID: emerging-malware.rules_343] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-malware.rules_343 mapped in 2.8s
#
# Processing rule 344/497: emerging-malware.rules_344
# [Rule ID: emerging-malware.rules_344] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Alternative Protocol",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.7"
#   }
# }
# ```
#
# Rule ID emerging-malware.rules_344 mapped in 2.5s
#
# Processing rule 345/497: emerging-malware.rules_345
# [Rule ID: emerging-malware.rules_345] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Command and Control Channel",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-malware.rules_345 mapped in 2.7s
#
# Processing rule 346/497: emerging-malware.rules_346
# [Rule ID: emerging-malware.rules_346] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Command and Control Channel",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0013",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0008",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-malware.rules_346 mapped in 3.5s
#
# Processing rule 347/497: emerging-malware.rules_347
# [Rule ID: emerging-malware.rules_347] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.95"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1047",
#     "mitre_technique_name": "Windows Management Instrumentation",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.65"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.45"
#   }
# }
# ```
#
# Rule ID emerging-malware.rules_347 mapped in 2.9s
#
# Processing rule 348/497: tor.rules_348
# [Rule ID: tor.rules_348] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Alternative Protocol",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1573",
#     "mitre_technique_name": "Encrypted Channel",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID tor.rules_348 mapped in 2.3s
#
# Processing rule 349/497: tor.rules_349
# [Rule ID: tor.rules_349] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0004",
#     "mitre_tactic_name": "Discovery",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Alternative Protocol",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1573",
#     "mitre_technique_name": "Encrypted Channel",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID tor.rules_349 mapped in 3.0s
#
# Processing rule 350/497: tor.rules_350
# [Rule ID: tor.rules_350] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1573",
#     "mitre_technique_name": "Encrypted Channel",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Alternative Protocol",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID tor.rules_350 mapped in 3.2s
#
# Processing rule 351/497: tor.rules_351
# [Rule ID: tor.rules_351] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Alternative Protocol",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1573",
#     "mitre_technique_name": "Encrypted Channel",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID tor.rules_351 mapped in 3.0s
#
# Processing rule 352/497: tor.rules_352
# [Rule ID: tor.rules_352] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Alternative Protocol",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1573",
#     "mitre_technique_name": "Encrypted Channel",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID tor.rules_352 mapped in 5.3s
#
# Processing rule 353/497: tor.rules_353
# [Rule ID: tor.rules_353] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0004",
#     "mitre_tactic_name": "Discovery",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Alternative Protocol",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1573",
#     "mitre_technique_name": "Encrypted Channel",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID tor.rules_353 mapped in 2.3s
#
# Processing rule 354/497: tor.rules_354
# [Rule ID: tor.rules_354] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Alternative Protocol",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1573",
#     "mitre_technique_name": "Encrypted Channel",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID tor.rules_354 mapped in 2.7s
#
# Processing rule 355/497: tor.rules_355
# [Rule ID: tor.rules_355] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Alternative Protocol",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1573",
#     "mitre_technique_name": "Encrypted Channel",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID tor.rules_355 mapped in 2.4s
#
# Processing rule 356/497: tor.rules_356
# [Rule ID: tor.rules_356] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0004",
#     "mitre_tactic_name": "Discovery",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Alternative Protocol",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1573",
#     "mitre_technique_name": "Encrypted Channel",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID tor.rules_356 mapped in 4.0s
#
# Processing rule 357/497: tor.rules_357
# [Rule ID: tor.rules_357] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1573",
#     "mitre_technique_name": "Encrypted Channel",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID tor.rules_357 mapped in 3.1s
#
# Processing rule 358/497: emerging-web_specific_apps.rules_358
# [Rule ID: emerging-web_specific_apps.rules_358] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1190",
#     "mitre_technique_name": "Exploit Public-Facing Application",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.95"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1059",
#     "mitre_technique_name": "Command-Line Interface",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1053",
#     "mitre_technique_name": "Scheduled Task/Job",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-web_specific_apps.rules_358 mapped in 2.6s
#
# Processing rule 359/497: emerging-web_specific_apps.rules_359
# [Rule ID: emerging-web_specific_apps.rules_359] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1059",
#     "mitre_technique_name": "Command-Line Interface",
#     "mitre_tactic_id": "TA0006",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1059.003",
#     "mitre_technique_name": "PowerShell",
#     "mitre_tactic_id": "TA0006",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1059.001",
#     "mitre_technique_name": "Command and Scripting Interpreter",
#     "mitre_tactic_id": "TA0006",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.70"
#   }
# }
# ```
#
# Rule ID emerging-web_specific_apps.rules_359 mapped in 4.7s
#
# Processing rule 360/497: emerging-web_specific_apps.rules_360
# [Rule ID: emerging-web_specific_apps.rules_360] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1190",
#     "mitre_technique_name": "Exploit Public-Facing Application",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.95"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1059",
#     "mitre_technique_name": "Command-Line Interface",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1059",
#     "mitre_technique_name": "Command-Line Interface",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-web_specific_apps.rules_360 mapped in 2.4s
#
# Processing rule 361/497: emerging-web_specific_apps.rules_361
# [Rule ID: emerging-web_specific_apps.rules_361] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1059",
#     "mitre_technique_name": "Command and Scripting Interpreter",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1053",
#     "mitre_technique_name": "Scheduled Task/Job",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1057",
#     "mitre_technique_name": "Process Discovery",
#     "mitre_tactic_id": "TA0003",
#     "mitre_tactic_name": "Discovery",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-web_specific_apps.rules_361 mapped in 3.3s
#
# Processing rule 362/497: emerging-web_specific_apps.rules_362
# [Rule ID: emerging-web_specific_apps.rules_362] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1190",
#     "mitre_technique_name": "Exploit Public-Facing Application",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1059",
#     "mitre_technique_name": "Command-Line Interface",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.70"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1053",
#     "mitre_technique_name": "Scheduled Task/Job",
#     "mitre_tactic_id": "TA0003",
#     "mitre_tactic_name": "Persistence",
#     "confidence_score": "0.60"
#   }
# }
# ```
#
# Rule ID emerging-web_specific_apps.rules_362 mapped in 2.4s
#
# Processing rule 363/497: emerging-web_specific_apps.rules_363
# [Rule ID: emerging-web_specific_apps.rules_363] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1190",
#     "mitre_technique_name": "Exploit Public-Facing Application",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1059",
#     "mitre_technique_name": "Command-Line Interface",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.70"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1053",
#     "mitre_technique_name": "Scheduled Task/Job",
#     "mitre_tactic_id": "TA0003",
#     "mitre_tactic_name": "Persistence",
#     "confidence_score": "0.60"
#   }
# }
# ```
#
# Rule ID emerging-web_specific_apps.rules_363 mapped in 2.6s
#
# Processing rule 364/497: emerging-web_specific_apps.rules_364
# [Rule ID: emerging-web_specific_apps.rules_364] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1190",
#     "mitre_technique_name": "Exploit Public-Facing Application",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1059",
#     "mitre_technique_name": "Command-Line Interface",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.70"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1053",
#     "mitre_technique_name": "Scheduled Task/Job",
#     "mitre_tactic_id": "TA0003",
#     "mitre_tactic_name": "Persistence",
#     "confidence_score": "0.60"
#   }
# }
# ```
#
# Rule ID emerging-web_specific_apps.rules_364 mapped in 2.4s
#
# Processing rule 365/497: emerging-web_specific_apps.rules_365
# [Rule ID: emerging-web_specific_apps.rules_365] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1190",
#     "mitre_technique_name": "Exploit Public-Facing Application",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1059",
#     "mitre_technique_name": "Command-Line Interface",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.70"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1053",
#     "mitre_technique_name": "Scheduled Task/Job",
#     "mitre_tactic_id": "TA0003",
#     "mitre_tactic_name": "Persistence",
#     "confidence_score": "0.60"
#   }
# }
# ```
#
# Rule ID emerging-web_specific_apps.rules_365 mapped in 3.1s
#
# Processing rule 366/497: emerging-web_specific_apps.rules_366
# [Rule ID: emerging-web_specific_apps.rules_366] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1190",
#     "mitre_technique_name": "Exploit Public-Facing Application",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.95"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1059",
#     "mitre_technique_name": "Command-Line Interface",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1053",
#     "mitre_technique_name": "Scheduled Task/Job",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-web_specific_apps.rules_366 mapped in 2.6s
#
# Processing rule 367/497: emerging-web_specific_apps.rules_367
# [Rule ID: emerging-web_specific_apps.rules_367] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1190",
#     "mitre_technique_name": "Exploit Public-Facing Application",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.95"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1059",
#     "mitre_technique_name": "Command-Line Interface",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1053",
#     "mitre_technique_name": "Scheduled Task/Job",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-web_specific_apps.rules_367 mapped in 2.8s
#
# Processing rule 368/497: emerging-netbios.rules_368
# [Rule ID: emerging-netbios.rules_368] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0007",
#     "mitre_tactic_name": "Discovery",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1047",
#     "mitre_technique_name": "Windows Management Instrumentation",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1021",
#     "mitre_technique_name": "Remote Services",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-netbios.rules_368 mapped in 2.5s
#
# Processing rule 369/497: emerging-netbios.rules_369
# [Rule ID: emerging-netbios.rules_369] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1210",
#     "mitre_technique_name": "Exploitation for Client Execution",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1047",
#     "mitre_technique_name": "Windows Management Instrumentation",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-netbios.rules_369 mapped in 2.8s
#
# Processing rule 370/497: emerging-netbios.rules_370
# [Rule ID: emerging-netbios.rules_370] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0007",
#     "mitre_tactic_name": "Discovery",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1047",
#     "mitre_technique_name": "Windows Management Instrumentation",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1021",
#     "mitre_technique_name": "Remote Services",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-netbios.rules_370 mapped in 2.3s
#
# Processing rule 371/497: emerging-netbios.rules_371
# [Rule ID: emerging-netbios.rules_371] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1020",
#     "mitre_technique_name": "Automated Exfiltration",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-netbios.rules_371 mapped in 3.0s
#
# Processing rule 372/497: emerging-netbios.rules_372
# [Rule ID: emerging-netbios.rules_372] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Standard Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1070",
#     "mitre_technique_name": "Indicator Removal on Host",
#     "mitre_tactic_id": "TA0004",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-netbios.rules_372 mapped in 2.5s
#
# Processing rule 373/497: emerging-netbios.rules_373
# [Rule ID: emerging-netbios.rules_373] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0007",
#     "mitre_tactic_name": "Discovery",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Command and Control Channel",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-netbios.rules_373 mapped in 2.4s
#
# Processing rule 374/497: emerging-netbios.rules_374
# [Rule ID: emerging-netbios.rules_374] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0007",
#     "mitre_tactic_name": "Discovery",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1047",
#     "mitre_technique_name": "Windows Management Instrumentation",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1020",
#     "mitre_technique_name": "Automated Exfiltration",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-netbios.rules_374 mapped in 2.8s
#
# Processing rule 375/497: emerging-netbios.rules_375
# [Rule ID: emerging-netbios.rules_375] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1070",
#     "mitre_technique_name": "Indicator Removal on Host",
#     "mitre_tactic_id": "TA0004",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-netbios.rules_375 mapped in 3.1s
#
# Processing rule 376/497: emerging-netbios.rules_376
# [Rule ID: emerging-netbios.rules_376] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1070",
#     "mitre_technique_name": "Indicator Removal on Host",
#     "mitre_tactic_id": "TA0004",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.60"
#   }
# }
# ```
#
# Rule ID emerging-netbios.rules_376 mapped in 3.3s
#
# Processing rule 377/497: emerging-netbios.rules_377
# [Rule ID: emerging-netbios.rules_377] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1021",
#     "mitre_technique_name": "Remote Services",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Initial Access",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-netbios.rules_377 mapped in 2.4s
#
# Processing rule 378/497: emerging-hunting.rules_378
# [Rule ID: emerging-hunting.rules_378] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1027",
#     "mitre_technique_name": "Obfuscated Files or Information",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1070",
#     "mitre_technique_name": "Indicator Removal on Host",
#     "mitre_tactic_id": "TA0006",
#     "mitre_tactic_name": "Collection",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-hunting.rules_378 mapped in 2.9s
#
# Processing rule 379/497: emerging-hunting.rules_379
# [Rule ID: emerging-hunting.rules_379] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1027",
#     "mitre_technique_name": "Obfuscated Files or Information",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.70"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Command and Control Channel",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.60"
#   }
# }
# ```
#
# Rule ID emerging-hunting.rules_379 mapped in 2.8s
#
# Processing rule 380/497: emerging-hunting.rules_380
# [Rule ID: emerging-hunting.rules_380] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1203",
#     "mitre_technique_name": "Exploitation for Client Execution",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1059",
#     "mitre_technique_name": "Command-Line Interface",
#     "mitre_tactic_id": "TA0006",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.75"
#   },
# ...
# [Rule ID: emerging-remote_access.rules_480] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1046",
#     "mitre_technique_name": "Network Service Scanning",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Discovery",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1040",
#     "mitre_technique_name": "Network Sniffing",
#     "mitre_tactic_id": "TA0007",
#     "mitre_tactic_name": "Collection",
#     "confidence_score": "0.70"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1020",
#     "mitre_technique_name": "Automated Exfiltration",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.60"
#   }
# }
# ```
#
# Rule ID emerging-remote_access.rules_480 mapped in 2.4s
#
# Processing rule 481/497: emerging-remote_access.rules_481
# [Rule ID: emerging-remote_access.rules_481] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-remote_access.rules_481 mapped in 2.4s
#
# Processing rule 482/497: emerging-remote_access.rules_482
# [Rule ID: emerging-remote_access.rules_482] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Alternative Protocol",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.70"
#   }
# }
# ```
#
# Rule ID emerging-remote_access.rules_482 mapped in 2.3s
#
# Processing rule 483/497: emerging-remote_access.rules_483
# [Rule ID: emerging-remote_access.rules_483] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0013",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1070",
#     "mitre_technique_name": "Indicator Removal on Host",
#     "mitre_tactic_id": "TA0006",
#     "mitre_tactic_name": "Defense Evasion",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-remote_access.rules_483 mapped in 2.5s
#
# Processing rule 484/497: emerging-remote_access.rules_484
# [Rule ID: emerging-remote_access.rules_484] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-remote_access.rules_484 mapped in 2.7s
#
# Processing rule 485/497: emerging-remote_access.rules_485
# [Rule ID: emerging-remote_access.rules_485] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-remote_access.rules_485 mapped in 3.1s
#
# Processing rule 486/497: emerging-remote_access.rules_486
# [Rule ID: emerging-remote_access.rules_486] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1071",
#     "mitre_technique_name": "Application Layer Protocol",
#     "mitre_tactic_id": "TA0007",
#     "mitre_tactic_name": "Discovery",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1106",
#     "mitre_technique_name": "Execution through API",
#     "mitre_tactic_id": "TA0002",
#     "mitre_tactic_name": "Execution",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID emerging-remote_access.rules_486 mapped in 2.4s
#
# Processing rule 487/497: emerging-remote_access.rules_487
# [Rule ID: emerging-remote_access.rules_487] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1020",
#     "mitre_technique_name": "Automated Exfiltration",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1078",
#     "mitre_technique_name": "Valid Accounts",
#     "mitre_tactic_id": "TA0006",
#     "mitre_tactic_name": "Credential Access",
#     "confidence_score": "0.70"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1046",
#     "mitre_technique_name": "Network Service Scanning",
#     "mitre_tactic_id": "TA0001",
#     "mitre_tactic_name": "Discovery",
#     "confidence_score": "0.60"
#   }
# }
# ```
#
# Rule ID emerging-remote_access.rules_487 mapped in 2.4s
#
# Processing rule 488/497: compromised.rules_488
# [Rule ID: compromised.rules_488] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0004",
#     "mitre_tactic_name": "Discovery",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Command and Control Channel",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID compromised.rules_488 mapped in 2.3s
#
# Processing rule 489/497: compromised.rules_489
# [Rule ID: compromised.rules_489] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Command and Control Channel",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.70"
#   }
# }
# ```
#
# Rule ID compromised.rules_489 mapped in 2.6s
#
# Processing rule 490/497: compromised.rules_490
# [Rule ID: compromised.rules_490] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0004",
#     "mitre_tactic_name": "Discovery",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Command and Control Channel",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0011",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.65"
#   }
# }
# ```
#
# Rule ID compromised.rules_490 mapped in 3.0s
#
# Processing rule 491/497: compromised.rules_491
# [Rule ID: compromised.rules_491] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Command and Control Channel",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.70"
#   }
# }
# ```
#
# Rule ID compromised.rules_491 mapped in 2.7s
#
# Processing rule 492/497: compromised.rules_492
# [Rule ID: compromised.rules_492] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Command and Control Channel",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.70"
#   }
# }
# ```
#
# Rule ID compromised.rules_492 mapped in 2.8s
#
# Processing rule 493/497: compromised.rules_493
# [Rule ID: compromised.rules_493] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.70"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Command and Control Channel",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.60"
#   }
# }
# ```
#
# Rule ID compromised.rules_493 mapped in 3.3s
#
# Processing rule 494/497: compromised.rules_494
# [Rule ID: compromised.rules_494] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.70"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Command and Control Channel",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.60"
#   }
# }
# ```
#
# Rule ID compromised.rules_494 mapped in 2.7s
#
# Processing rule 495/497: compromised.rules_495
# [Rule ID: compromised.rules_495] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Command and Control Channel",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.70"
#   }
# }
# ```
#
# Rule ID compromised.rules_495 mapped in 3.1s
#
# Processing rule 496/497: compromised.rules_496
# [Rule ID: compromised.rules_496] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Command and Control Channel",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.70"
#   }
# }
# ```
#
# Rule ID compromised.rules_496 mapped in 3.2s
#
# Processing rule 497/497: compromised.rules_497
# [Rule ID: compromised.rules_497] Raw response:
# ```json
# {
#   "most_likely_technique": {
#     "mitre_technique_id": "T1043",
#     "mitre_technique_name": "Commonly Used Port",
#     "mitre_tactic_id": "TA0005",
#     "mitre_tactic_name": "Command and Control",
#     "confidence_score": "0.85"
#   },
#   "second_most_likely_technique": {
#     "mitre_technique_id": "T1105",
#     "mitre_technique_name": "Ingress Tool Transfer",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.75"
#   },
#   "third_most_likely_technique": {
#     "mitre_technique_id": "T1048",
#     "mitre_technique_name": "Exfiltration Over Command and Control Channel",
#     "mitre_tactic_id": "TA0010",
#     "mitre_tactic_name": "Exfiltration",
#     "confidence_score": "0.70"
#   }
# }
# ```
#
# Rule ID compromised.rules_497 mapped in 2.5s
#
#
# Saving 497 mapped rules to 'testDataMapped_with_confidence.json'...
# Done! Mapped 497 of 497 successfully.

# %%
# import pandas as pd
# # Load JSON file
# data = pd.read_json("testDataMapped.json")
# # Save to CSV
# data.to_csv("testDataMapped.csv", index=False)

# %%
import pandas as pd
#Load JSON file
data = pd.read_json("testDataMapped_with_confidence.json")
# # Save to CSV
data.to_csv("testDataMapped_with_confidence.csv", index=False)
